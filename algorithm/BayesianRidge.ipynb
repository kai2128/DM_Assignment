# %%
# %%capture
# %run ./algorithm/read_data.ipynb

# %% [markdown]
# ### Bayesian Ridge Regressor

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import GridSearchCV

# %%
br = BayesianRidge()
br.fit(X_train, y_train)
# Out:
# BayesianRidge()

# %%
train_test_report(br)
# Out:
# Train score: 		         0.8937
# Test score: 		         0.8939

# %%
plot_prediction_compare_ori(br)

# %%
regression_report(br.predict(X_train), y_test)
# Out:
# Accuracy score: 			         0.8937
# R-squared score: 			         0.8937
# Mean Absolute Error(MAE): 		      1697.9230
# Mean Squared Error (MSE): 		   4937146.0901
# Root Mean Squared Error (RSME): 	      2221.9690
