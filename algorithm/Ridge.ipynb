# %%
# %%capture
# %run ./algorithm/read_data.ipynb

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
rdg = Ridge()
rdg.fit(X_train, y_train)
# Out:
# Ridge()

# %%
train_test_report(rdg)
# Out:
# Train score: 		         0.8937
# Test score: 		         0.8939

# %%
plot_prediction_compare_ori(rdg)

# %%
regression_report_model(rdg)
# Out:
# Accuracy score: 			         0.8939
# R-squared score: 			         0.8939
# Mean Absolute Error(MAE): 		      1698.0957
# Mean Squared Error (MSE): 		   5146987.8223
# Root Mean Squared Error (RSME): 	      2268.6974
