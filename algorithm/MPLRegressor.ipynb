# %%
# %%capture
# %run ./algorithm/read_data.ipynb

# %% [markdown]
# ### MPL Regressor

# %%
from sklearn.neural_network import MLPRegressor

# %%
mpl = MLPRegressor()
mpl.fit(X_train, y_train)
# Out:
# F:\hw\DM\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor()

# %%
train_test_report(mpl)
# Out:
# Train score: 		         0.8777
# Test score: 		         0.8771

# %%
plot_prediction_compare_ori(mpl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_65248/4011204505.py in <module>
# ----> 1 plot_prediction_compare_ori(rdg)
#
# NameError: name 'rdg' is not defined

# %%
plot_prediction_compare_ori(mpl)

# %%
regression_report_model(mpl)
# Out:
# Accuracy score: 			         0.8772
# R-squared score: 			         0.8771
# Mean Absolute Error(MAE): 		      1804.5456
# Mean Squared Error (MSE): 		   5960996.8405
# Root Mean Squared Error (RSME): 	      2441.5153
