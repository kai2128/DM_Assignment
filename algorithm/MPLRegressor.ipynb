# %%
# %%capture
# %run ./algorithm/read_data.ipynb

# %% [markdown]
# ### MPL Regressor

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor()
sgd.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
train_test_report(sgd)
# Out:
# Train score: 		         0.8935
# Test score: 		         0.8938

# %%
plot_prediction_compare_ori(sgd)

# %%
plot_prediction_compare_ori(sgd, X_train, y_train)

# %%
regression_report_model(sgd)
# Out:
# Accuracy score: 			         0.8938
# R-squared score: 			         0.8938
# Mean Absolute Error(MAE): 		      1702.7654
# Mean Squared Error (MSE): 		   5149837.0113
# Root Mean Squared Error (RSME): 	      2269.3252
